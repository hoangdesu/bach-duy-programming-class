# %% [markdown]
# # Welcome to Notebook

# %%
print('hello notebook')
# Out:
# hello notebook

# %% [markdown]
# ### this is a h3
#
# - line 1
# - line 2

# %%
print(name)
# Out:
# Bach Duy

# %%
# name = 'Duy'
name = 'Bach Duy'

# %%
for i in range(20):
    print(i, 'hello')
# Out:
# 0 hello
# 1 hello
# 2 hello
# 3 hello
# 4 hello
# 5 hello
# 6 hello
# 7 hello
# 8 hello
# 9 hello
# 10 hello
# 11 hello
# 12 hello
# 13 hello
# 14 hello
# 15 hello
# 16 hello
# 17 hello
# 18 hello
# 19 hello

# %%
print(name)
# Out:
# Bach Duy

# %%
from PIL import Image

image = Image.open('generated_image_2026-03-27 15:49:09.876612.png')
# image.show()
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1408x768>
